# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../inverton_lengths.csv")
sns.histplot(data=df, x="length", weights="count", multiple="dodge", binwidth=20)

plt.show()

# %%
df['length'].min()
# Out:
# 53

# %%
df['length'].max()
# Out:
# 749
